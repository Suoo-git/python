# %%
lotto = set()
import random
while True:    
    num = random.randint(1,45)
    lotto.add(num)
    if len(lotto) == 6:
        break

sortlotto = list(lotto)
sortlotto.sort(reverse=False)
print(sortlotto)
# Out:
# [2, 13, 35, 36, 37, 42]

# %% [markdown]
# ## 거스름 돈
# - 당신은 음식점의 계산을 도와주는 점원입니다. 카운터에는 거스름 돈으로 사용할 500원, 100원, 50원, 10원 짜리 동전이 무한히 존재한다고 가정합니다. 손님에게 거슬러 주어야 할 돈이 N원일 때 거슬러 주어야 할 동전의 최소 개수를 구하세요. 단, 거슬러 줘야 할 돈 N은 항상 10의 배수입니다.

# %%
money = 1020
count = 0
while True :
    if money >= 500:
        count += (money // 500)
        money %= 500
    elif money >= 100:
        count += (money // 100)
        money %= 100
    elif money >= 50:
        count += (money // 50)
        money %= 50
    elif money >= 10:
        count += (money // 10)
        money %= 10
    else: break   
    
count
# Out:
# 4

# %%
money_count = [500,100,50,10]
money = 1000450
count = 0
for coin in money_count:
    if money>= coin:
        count+= (money // coin)
        money %= coin
# Out:
# 2005

# %% [markdown]
# ## 1이 될 때까지
# - 어떠한 수 N이 될 때까지 다음의 두 과정 중 하나를 반복적으로 선택하여 수행하려고 합니다. 단, 두번째 연산은 N이 K로 나누어 떨어질 때만 선택할 수 있습니다.
# 1. N에서 1을 뺍니다.
# 2. N을 K로 나눕니다.
# - 예를 들어 N이 17, K가 4라고 가정합시다. 이 때 1번의 과정을 한 번 수행하면 N은 16이 됩니다. 이후에 2번의 과정을 두 번 수행하면 N은 1이 됩니다. 결과적으로 이 경우 전체 과정을 실행한 횟수는 3이 됩니다. 이는 N을 1로 만드는 최소 횟수입니다.
# - N과 K가 주어질 때 N이 1이 될 때까지 1번 혹은 2번의 과정을 수행해야 하는 최소 횟수를 구하는 프로그램을 작성하세요.

# %%
n = int(input())
k = int(input())

count = 0

while n > 1:
    if n%k == 0:
        n = n//k
    else:
        n = n-1
        # count +=1
    count +=1
    if n == 1: break


print(count)
# Out:
# 25
# 5
# 2

# %% [markdown]
# ##List Comprehesion

# %%
result = []
for i in range(2,3):
    for j in range(1, 10):
        result.append(i*j)
print(result)

result = [ i * j for i in range(2,3) for j in range(1,10)]
print(result)

name = [ i for i in range(ord('a'), ord('z')+1)]
print(name)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]
# [2, 4, 6, 8, 10, 12, 14, 16, 18]
# [97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122]

# %% [markdown]
# ## Function

# %%
def watermelon(n):
    # print("수박" * (n // 2), end="")
    # if n % 2 != 0:
    #     print("수")

    buffer = ''
    buffer = "수박" *(n // 2)
    if n % 2 != 0:
        buffer += "수"
    return buffer
watermelon(11)


def numPlus(n):
    # plus = 0
    # for i in num:
    #     plus += int(i)
    # return plus

    num = list(str(n))
    num = map(int, num)
    return sum(num)

numPlus(111145)
# Out:
# (13, '수박수박수박수박수박수')

# %% [markdown]
# ## 마방진

# %%
m =  [ [0 for i in range(5)] for j in range(5)]
row = 0 
col = 2

m[row][col] = 1
for i in range(2,26):
    powrow = row
    powcol = col
    row -= 1
    col += 1

    if row <0:
        row =4
    if col > 4:
        col = 0

    if m[row][col] != 0:
    #    row += 2
    #    col -= 1 
        row = powrow + 1
        col = powcol
    m[row][col] = i
# Out:
#   File "<ipython-input-156-7008a2142cc3>", line 24
#     print([s for b in [for a in m]])
#                        ^
# SyntaxError: invalid syntax

# %%
import requests as req
res = req.get('http://ggoreb.com/quiz/encrypt_string.txt')
txt = res.text
text = res.text
# print(text)

# k > m
# o > q
# e > g
text = list(text)
result = [ord(a) + 2  for a in text]  # A = 65, Z= 90  a= 97, z = 122
name = []
for i in result:

    if i == 91 or i == 92 or i == 123 or i== 124:
        i = i - 26

    if i == 34: # 스페이스
        i = 32

    if i == 48:
        i = 46
    name.append(i)
    print(i, end=" ")
# result.replace(105)
print("")
name1 = [chr(b) for b in name]

# for i in name:
#     a = i.replace('{', 'a')
#     name1.append(a)
# name1
# name.replace
for c in name1:
    print(c, end="")
# Out:
# 105 32 104 111 112 101 32 121 111 117 32 100 105 100 110 116 32 116 114 97 110 115 108 97 116 101 32 105 116 32 98 121 32 104 97 110 100 46 32 116 104 97 116 115 32 119 104 97 116 32 99 111 109 112 117 116 101 114 115 32 97 114 101 32 102 111 114 46 32 100 111 105 110 103 32 105 116 32 105 110 32 98 121 32 104 97 110 100 32 105 115 32 105 110 101 102 102 105 99 105 101 110 116 32 97 110 100 32 116 104 97 116 41 115 32 119 104 121 32 116 104 105 115 32 116 101 120 116 32 105 115 32 115 111 32 108 111 110 103 46 32 117 115 105 110 103 32 115 116 114 105 110 103 46 109 97 107 101 116 114 97 110 115 42 43 32 105 115 32 114 101 99 111 109 109 101 110 100 101 100 46 32 110 111 119 32 97 112 112 108 121 32 111 110 32 116 104 101 32 117 114 108 46
# i hope you didnt translate it by hand. thats what computers are for. doing it in by hand is inefficient and that)s why this text is so long. using string.maketrans*+ is recommended. now apply on the url.

# %%
import requests as req
res = req.get('http://ggoreb.com/quiz/encrypt_string.txt')
txt = res.text


for t in txt:
    if (97 <= ord(t) <=122):
        change = ord(t) + 2
    else:
        change = ord(t) 
    if  123<= change <= 124:
        change -=  26
    print(chr(change), end="")

before =  [chr(i)for i in range(ord('a'), ord('z') + 1)]
after = before[2:] + before[:2]

before  = ''.join(before)
after = ''.join(after)
ob = str.maketrans(before, after)
txt.maketrans(ob)
# Out:
# i hope you didnt translate it by hand. thats what computers are for. doing it in by hand is inefficient and that's why this text is so long. using string.maketrans() is recommended. now apply on the url.
# {97: 99,
#  98: 100,
#  99: 101,
#  100: 102,
#  101: 103,
#  102: 104,
#  103: 105,
#  104: 106,
#  105: 107,
#  106: 108,
#  107: 109,
#  108: 110,
#  109: 111,
#  110: 112,
#  111: 113,
#  112: 114,
#  113: 115,
#  114: 116,
#  115: 117,
#  116: 118,
#  117: 119,
#  118: 120,
#  119: 121,
#  120: 122,
#  121: 97,
#  122: 98}
