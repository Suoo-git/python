# %%
import requests
res = requests.get('http://ggoreb.com/api/shop.jsp')

result = res.json()
for item in list:
    item.g

# %%
 # 모든 lng, lat 출력
# for i in range(0,len(result['list'])):
#     print("lng : ",result['list'][i]['lng'], "lat : ",result['list'][i]['lat'])
item.

list = result.get('list')

for item in list:
    lat = item.get('lat')
    lng = item.get('lng')
    print(lng, lat)
